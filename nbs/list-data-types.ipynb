# %%
# %pip install requests
# Out:
# Requirement already satisfied: requests in /home/sufyan/Analytics-api/venv/lib/python3.12/site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/sufyan/Analytics-api/venv/lib/python3.12/site-packages (from requests) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /home/sufyan/Analytics-api/venv/lib/python3.12/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sufyan/Analytics-api/venv/lib/python3.12/site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sufyan/Analytics-api/venv/lib/python3.12/site-packages (from requests) (2026.2.25)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
path= "/api/events/"
base_url = "http://localhost:8000"
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8000/api/events/'

# %%
response = requests.get(endpoint)
print(response.ok)
# Out:
# True

# %%
response = requests.get(endpoint)
print(response.status_code)
if response.ok:
    data = response.json()
    print(data, type(data), data.get('items'))
# Out:
# 200
# {'results': [1, 2, 3, 4, 5]} <class 'dict'> None
