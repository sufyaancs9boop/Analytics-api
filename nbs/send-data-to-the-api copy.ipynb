# %%
# %pip install requests
# Out:
# Requirement already satisfied: requests in e:\analytics-api\venv\lib\site-packages (2.33.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\analytics-api\venv\lib\site-packages (from requests) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in e:\analytics-api\venv\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in e:\analytics-api\venv\lib\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in e:\analytics-api\venv\lib\site-packages (from requests) (2026.2.25)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
path= "/api/events/"
base_url = "http://localhost:8000"
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8000/api/events/'

# %%
data={"page": "/test+"}

# %%
import json
json.dumps(data)
# Out:
# '{"page": "/test+"}'

# %%
headers = {"Content-Type": "application/json"
           }

response = requests.post(endpoint, headers=headers, data=json.dumps(data))
print(response.status_code)
print(response.headers)
print(response.status_code)
print(response.text)
 
if response.ok:
    data = response.json() 
    print(data, type(data), data.get('items'))
else:
    print(response.text)
# Out:
# 200
# {'date': 'Tue, 31 Mar 2026 19:41:33 GMT', 'server': 'uvicorn', 'content-length': '10', 'content-type': 'application/json'}
# 200
# {"id":123}
# {'id': 123} <class 'dict'> None

# %%
detail_path= "/api/events/12"

detail_endpoint = f"{base_url}{detail_path}"

response = requests.put(detail_endpoint, json={"description":"Hello world"})
print(response.status_code)
print(response.headers)
print(response.status_code)
print(response.text)
 
if response.ok:
    data = response.json() 
    print(data, type(data), data.get('items'))
else:
    print(response.text)
# Out:
# 405
# {'date': 'Tue, 31 Mar 2026 21:10:27 GMT', 'server': 'uvicorn', 'allow': 'GET', 'content-length': '31', 'content-type': 'application/json'}
# 405
# {"detail":"Method Not Allowed"}
# {"detail":"Method Not Allowed"}
