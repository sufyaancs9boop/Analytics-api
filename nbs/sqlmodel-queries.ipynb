# %%
import sys
from pathlib import Path

# %%
src_path = Path("../src").resolve()
sys.path.append(str(src_path))

# %%
print(src_path)         # should print E:\Analytics-api\src
print(src_path.exists()) # should print True
import os
print(os.listdir(src_path))  # should show api folder
# Out:
# E:\Analytics-api\src
# True
# ['api', 'main.py', '__init__.py', '__pycache__']

# %%
# Add this debug cell after the path setup
import os
for root, dirs, files in os.walk(src_path):
    for file in files:
        if file == "__init__.py":
            print(os.path.join(root, file))
# Out:
# E:\Analytics-api\src\__init__.py
# E:\Analytics-api\src\api\__init__.py
# E:\Analytics-api\src\api\db\__init__.py
# E:\Analytics-api\src\api\events\__init__.py

# %%
import importlib
import api
print(api)
# Out:
# <module 'api' from 'E:\\Analytics-api\\src\\api\\__init__.py'>

# %%
from sqlmodel import Session, select
from api.db.sessions import engine
from api.events.models import EventModel
from timescaledb.hyperfunctions import time_bucket
from pprint import pprint

# %%
with Session(engine) as session:
    query = select(EventModel).order_by(EventModel.updated_at.asc()).limit(10)
    compiled_query = query.compile(compile_kwargs={"literal_binds": True})
    print(compiled_query)
    print("")
    print(str(query))
# Out:
# SELECT eventmodel.id, eventmodel.time, eventmodel.page, eventmodel.description, eventmodel.updated_at
# FROM eventmodel ORDER BY eventmodel.updated_at ASC
#  LIMIT 10
#
# SELECT eventmodel.id, eventmodel.time, eventmodel.page, eventmodel.description, eventmodel.updated_at
# FROM eventmodel ORDER BY eventmodel.updated_at ASC
#  LIMIT :param_1

# %%
# %pip install faker
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
